# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

import time
import csv
# Import API key
#import api_keys

from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #city = city.replace(" ", "%20")
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
windspeed = []
counter = 1
print(f"Beginning Data Retrieval")
print(f"-------------------------------")
for city in cities:
    try: 
        quryurl = url + "appid=" + api_key + "&q=" + city
        response = requests.get(quryurl).json()
        cityname.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        maxtemp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        windspeed.append(response["wind"]["speed"])
        cityrecord = response["name"]
        print(f"Processing Record {counter} of {len(cities)}| {cityrecord}")
        counter = counter + 1
        #sets = sets + 1
        time.sleep(1)
    except:
        print("City not found. Skipping..........")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of 603| Lagoa
# Processing Record 2 of 603| Carnarvon
# Processing Record 3 of 603| Mataura
# Processing Record 4 of 603| Ushuaia
# Processing Record 5 of 603| Bambous Virieux
# Processing Record 6 of 603| Linxia
# City not found. Skipping..........
# Processing Record 7 of 603| Manadhoo
# Processing Record 8 of 603| San Carlos de Bariloche
# City not found. Skipping..........
# Processing Record 9 of 603| Sibu
# Processing Record 10 of 603| Rio Gallegos
# Processing Record 11 of 603| Sabha
# Processing Record 12 of 603| Bani
# Processing Record 13 of 603| Punta Arenas
# Processing Record 14 of 603| Dikson
# Processing Record 15 of 603| Xining
# Processing Record 16 of 603| Jamestown
# Processing Record 17 of 603| Vila do Maio
# Processing Record 18 of 603| Ponta do Sol
# Processing Record 19 of 603| Albany
# Processing Record 20 of 603| Inta
# Processing Record 21 of 603| Rikitea
# Processing Record 22 of 603| Ribeira Grande
# City not found. Skipping..........
# Processing Record 23 of 603| Itarema
# Processing Record 24 of 603| Hithadhoo
# Processing Record 25 of 603| Hilo
# Processing Record 26 of 603| Bonwapitse
# Processing Record 27 of 603| Iquitos
# Processing Record 28 of 603| Imbituba
# Processing Record 29 of 603| Bredasdorp
# Processing Record 30 of 603| Chiredzi
# Processing Record 31 of 603| New Norfolk
# Processing Record 32 of 603| Raudeberg
# City not found. Skipping..........
# Processing Record 33 of 603| Bluff
# Processing Record 34 of 603| Xinxiang
# Processing Record 35 of 603| Acapulco
# Processing Record 36 of 603| Kushtagi
# Processing Record 37 of 603| Dimbokro
# Processing Record 38 of 603| Tatvan
# Processing Record 39 of 603| Cape Town
# Processing Record 40 of 603| Castro
# Processing Record 41 of 603| Quzhou
# Processing Record 42 of 603| Bilibino
# Processing Record 43 of 603| Puerto Ayora
# Processing Record 44 of 603| Manggar
# Processing Record 45 of 603| Busselton
# Processing Record 46 of 603| East London
# Processing Record 47 of 603| Nikolskoye
# Processing Record 48 of 603| Zharkent
# City not found. Skipping..........
# Processing Record 49 of 603| Kloulklubed
# Processing Record 50 of 603| Upernavik
# Processing Record 51 of 603| Ambon
# Processing Record 52 of 603| Kapaa
# Processing Record 53 of 603| Mar del Plata
# Processing Record 54 of 603| Port Alfred
# Processing Record 55 of 603| Faya
# Processing Record 56 of 603| Dingle
# City not found. Skipping..........
# Processing Record 57 of 603| Nanortalik
# Processing Record 58 of 603| Yellowknife
# Processing Record 59 of 603| Salalah
# Processing Record 60 of 603| Wewak
# Processing Record 61 of 603| Kavieng
# Processing Record 62 of 603| Hobyo
# Processing Record 63 of 603| Trairi
# Processing Record 64 of 603| Port Hardy
# Processing Record 65 of 603| Hasaki
# Processing Record 66 of 603| Rotifunk
# City not found. Skipping..........
# Processing Record 67 of 603| Port-Gentil
# Processing Record 68 of 603| Mount Gambier
# Processing Record 69 of 603| Saskylakh
# Processing Record 70 of 603| Vanavara
# Processing Record 71 of 603| Tuktoyaktuk
# Processing Record 72 of 603| Hofn
# Processing Record 73 of 603| Fort Abbas
# Processing Record 74 of 603| Severo-Kurilsk
# Processing Record 75 of 603| Arraial do Cabo
# Processing Record 76 of 603| Portland
# Processing Record 77 of 603| Porto Novo
# Processing Record 78 of 603| Uray
# Processing Record 79 of 603| Powell River
# Processing Record 80 of 603| Erenhot
# Processing Record 81 of 603| Kununurra
# Processing Record 82 of 603| Punto Fijo
# Processing Record 83 of 603| Kodiak
# Processing Record 84 of 603| Vila Velha
# Processing Record 85 of 603| Wembley
# Processing Record 86 of 603| Honiara
# Processing Record 87 of 603| Ternate
# Processing Record 88 of 603| Vila Franca do Campo
# Processing Record 89 of 603| Kingaroy
# Processing Record 90 of 603| Pryazha
# Processing Record 91 of 603| Maroantsetra
# Processing Record 92 of 603| Chuy
# City not found. Skipping..........
# Processing Record 93 of 603| Caravelas
# Processing Record 94 of 603| Quelimane
# Processing Record 95 of 603| Yulara
# Processing Record 96 of 603| Tingo Maria
# City not found. Skipping..........
# Processing Record 97 of 603| Atuona
# Processing Record 98 of 603| Port Macquarie
# Processing Record 99 of 603| Vryburg
# Processing Record 100 of 603| Pleshanovo
# Processing Record 101 of 603| Hermanus
# City not found. Skipping..........
# Processing Record 102 of 603| Matara
# Processing Record 103 of 603| Touros
# City not found. Skipping..........
# Processing Record 104 of 603| Barry
# Processing Record 105 of 603| Nouakchott
# Processing Record 106 of 603| Richards Bay
# Processing Record 107 of 603| Khatanga
# Processing Record 108 of 603| Chokurdakh
# City not found. Skipping..........
# Processing Record 109 of 603| Jiuquan
# Processing Record 110 of 603| Avarua
# Processing Record 111 of 603| Atar
# Processing Record 112 of 603| Bethel
# Processing Record 113 of 603| Tiksi
# Processing Record 114 of 603| Verkhoyansk
# City not found. Skipping..........
# Processing Record 115 of 603| Lebu
# Processing Record 116 of 603| Sioux Lookout
# Processing Record 117 of 603| Colares
# Processing Record 118 of 603| Muros
# Processing Record 119 of 603| Vaini
# Processing Record 120 of 603| Seoul
# Processing Record 121 of 603| Cidreira
# Processing Record 122 of 603| Lasa
# Processing Record 123 of 603| Victoria
# Processing Record 124 of 603| Kawalu
# Processing Record 125 of 603| Oranjemund
# Processing Record 126 of 603| Oruro
# Processing Record 127 of 603| Vardo
# Processing Record 128 of 603| Airai
# Processing Record 129 of 603| Petropavlovsk-Kamchatskiy
# Processing Record 130 of 603| Kruisfontein
# Processing Record 131 of 603| West Wendover
# Processing Record 132 of 603| Bull Savanna
# Processing Record 133 of 603| Torredonjimeno
# Processing Record 134 of 603| Torbay
# Processing Record 135 of 603| Naze
# Processing Record 136 of 603| Bar Harbor
# City not found. Skipping..........
# Processing Record 137 of 603| Hami
# Processing Record 138 of 603| Komsomolskiy
# City not found. Skipping..........
# Processing Record 139 of 603| Waingapu
# Processing Record 140 of 603| Sorland
# Processing Record 141 of 603| Argelia
# Processing Record 142 of 603| Marshall
# Processing Record 143 of 603| Langsa
# Processing Record 144 of 603| Pershotravneve
# Processing Record 145 of 603| Sovetskiy
# City not found. Skipping..........
# Processing Record 146 of 603| Isparta
# Processing Record 147 of 603| Manta
# Processing Record 148 of 603| Qaanaaq
# Processing Record 149 of 603| Grinnell
# Processing Record 150 of 603| Iqaluit
# Processing Record 151 of 603| Cockburn Town
# Processing Record 152 of 603| Kudahuvadhoo
# Processing Record 153 of 603| Hokitika
# Processing Record 154 of 603| Matucana
# Processing Record 155 of 603| Conde
# Processing Record 156 of 603| Zhicheng
# Processing Record 157 of 603| Barrow
# City not found. Skipping..........
# City not found. Skipping..........
# City not found. Skipping..........
# Processing Record 158 of 603| Bilsanda
# Processing Record 159 of 603| Cabo San Lucas
# Processing Record 160 of 603| Casablanca
# Processing Record 161 of 603| Dubbo
# Processing Record 162 of 603| Huarmey
# City not found. Skipping..........
# Processing Record 163 of 603| Iwanai
# Processing Record 164 of 603| Guisa
# Processing Record 165 of 603| Flinders
# Processing Record 166 of 603| Saint-Philippe
# Processing Record 167 of 603| Chiang Kham
# Processing Record 168 of 603| Ambulu
# City not found. Skipping..........
# Processing Record 169 of 603| Ilulissat
# Processing Record 170 of 603| Aloleng
# Processing Record 171 of 603| Deputatskiy
# Processing Record 172 of 603| Lupiro
# Processing Record 173 of 603| Kaeo
# Processing Record 174 of 603| Mulchen
# Processing Record 175 of 603| Butaritari
# Processing Record 176 of 603| Cherskiy
# Processing Record 177 of 603| Bilma
# City not found. Skipping..........
# Processing Record 178 of 603| Norman Wells
# Processing Record 179 of 603| Bacabal
# Processing Record 180 of 603| Peterhead
# Processing Record 181 of 603| Alice Springs
# City not found. Skipping..........
# Processing Record 182 of 603| Bellmead
# Processing Record 183 of 603| Abay
# Processing Record 184 of 603| Ayan
# City not found. Skipping..........
# City not found. Skipping..........
# Processing Record 185 of 603| Bolivar
# Processing Record 186 of 603| Fortuna
# City not found. Skipping..........
# Processing Record 187 of 603| Tasiilaq
# Processing Record 188 of 603| Bubaque
# Processing Record 189 of 603| Padang
# Processing Record 190 of 603| Ushtobe
# Processing Record 191 of 603| Svetlogorsk
# Processing Record 192 of 603| Aldan
# Processing Record 193 of 603| Christchurch
# Processing Record 194 of 603| Nome
# Processing Record 195 of 603| Yumen
# Processing Record 196 of 603| Thompson
# Processing Record 197 of 603| Berlevag
# Processing Record 198 of 603| Gainesville
# Processing Record 199 of 603| Hailar
# Processing Record 200 of 603| Isangel
# Processing Record 201 of 603| Taywarah
# Processing Record 202 of 603| Borazjan
# Processing Record 203 of 603| Orocue
# Processing Record 204 of 603| Provideniya
# Processing Record 205 of 603| Geraldton
# Processing Record 206 of 603| Lichuan
# Processing Record 207 of 603| Bacalar
# Processing Record 208 of 603| Saint-Joseph
# Processing Record 209 of 603| Hobart
# Processing Record 210 of 603| Najran
# Processing Record 211 of 603| Oroquieta
# Processing Record 212 of 603| Nuevo Imperial
# Processing Record 213 of 603| Bunia
# Processing Record 214 of 603| Cumpas
# Processing Record 215 of 603| Port Lincoln
# Processing Record 216 of 603| Pereslavl-Zalesskiy
# Processing Record 217 of 603| Bathsheba
# Processing Record 218 of 603| Lorengau
# Processing Record 219 of 603| Kamaishi
# Processing Record 220 of 603| Suba
# City not found. Skipping..........
# Processing Record 221 of 603| Zhenlai
# Processing Record 222 of 603| El Sauzal
# Processing Record 223 of 603| Katsuura
# Processing Record 224 of 603| Meulaboh
# Processing Record 225 of 603| Binga
# Processing Record 226 of 603| Agadez
# Processing Record 227 of 603| Luderitz
# Processing Record 228 of 603| Sistranda
# City not found. Skipping..........
# Processing Record 229 of 603| Codrington
# Processing Record 230 of 603| Aksu
# Processing Record 231 of 603| San Patricio
# Processing Record 232 of 603| Paka
# Processing Record 233 of 603| Paamiut
# Processing Record 234 of 603| Pauini
# Processing Record 235 of 603| Petlad
# Processing Record 236 of 603| Daru
# Processing Record 237 of 603| Lavrentiya
# Processing Record 238 of 603| Olinda
# Processing Record 239 of 603| Rocha
# Processing Record 240 of 603| Longyearbyen
# Processing Record 241 of 603| Shelburne
# Processing Record 242 of 603| Carballo
# Processing Record 243 of 603| Turayf
# Processing Record 244 of 603| Mungwi
# Processing Record 245 of 603| Zhezkazgan
# Processing Record 246 of 603| Tambacounda
# Processing Record 247 of 603| Saint Anthony
# Processing Record 248 of 603| Nabire
# Processing Record 249 of 603| Srivardhan
# Processing Record 250 of 603| Ayorou
# Processing Record 251 of 603| Sardulgarh
# Processing Record 252 of 603| Yatou
# Processing Record 253 of 603| Taoudenni
# Processing Record 254 of 603| Rize
# Processing Record 255 of 603| Hachinohe
# Processing Record 256 of 603| Georgetown
# Processing Record 257 of 603| Inawashiro
# Processing Record 258 of 603| Ancud
# Processing Record 259 of 603| Oktyabrskoye
# Processing Record 260 of 603| Esperance
# Processing Record 261 of 603| Luba
# Processing Record 262 of 603| Tallahassee
# City not found. Skipping..........
# Processing Record 263 of 603| Guerrero Negro
# Processing Record 264 of 603| Zhigansk
# Processing Record 265 of 603| Baherden
# Processing Record 266 of 603| Nouadhibou
# Processing Record 267 of 603| Vung Tau
# Processing Record 268 of 603| Husavik
# Processing Record 269 of 603| Pandan
# Processing Record 270 of 603| Dzilam Gonzalez
# Processing Record 271 of 603| Sur
# Processing Record 272 of 603| Vredendal
# Processing Record 273 of 603| Jinka
# Processing Record 274 of 603| Duldurga
# Processing Record 275 of 603| Udarnyy
# City not found. Skipping..........
# Processing Record 276 of 603| Palafrugell
# Processing Record 277 of 603| Riverdale
# Processing Record 278 of 603| Zwedru
# Processing Record 279 of 603| Daoukro
# Processing Record 280 of 603| Henties Bay
# City not found. Skipping..........
# Processing Record 281 of 603| Sao Filipe
# Processing Record 282 of 603| Lata
# Processing Record 283 of 603| Gayeri
# Processing Record 284 of 603| Moctezuma
# Processing Record 285 of 603| Grojdibodu
# Processing Record 286 of 603| Maunabo
# Processing Record 287 of 603| Port Hedland
# Processing Record 288 of 603| Ixtapa
# Processing Record 289 of 603| San Cristobal
# Processing Record 290 of 603| San Luis
# Processing Record 291 of 603| Lompoc
# Processing Record 292 of 603| Shakawe
# Processing Record 293 of 603| Fougamou
# Processing Record 294 of 603| Mirnyy
# Processing Record 295 of 603| Rio Grande
# Processing Record 296 of 603| Dondo
# Processing Record 297 of 603| Pio IX
# Processing Record 298 of 603| Teocuitatlan de Corona
# Processing Record 299 of 603| Berezovyy
# Processing Record 300 of 603| Corsicana
# Processing Record 301 of 603| Smithers
# City not found. Skipping..........
# Processing Record 302 of 603| Kyaikkami
# Processing Record 303 of 603| Kupang
# Processing Record 304 of 603| Nyurba
# Processing Record 305 of 603| Jati
# Processing Record 306 of 603| Eyl
# Processing Record 307 of 603| Ukiah
# Processing Record 308 of 603| Port Elizabeth
# Processing Record 309 of 603| Coolum Beach
# Processing Record 310 of 603| Trincomalee
# Processing Record 311 of 603| Kaitangata
# Processing Record 312 of 603| Gizo
# Processing Record 313 of 603| Pisco
# Processing Record 314 of 603| Westport
# Processing Record 315 of 603| General Mamerto Natividad
# Processing Record 316 of 603| Saryg-Sep
# Processing Record 317 of 603| Santa Cruz de Tenerife
# Processing Record 318 of 603| Veraval
# Processing Record 319 of 603| Tura
# Processing Record 320 of 603| Mgandu
# Processing Record 321 of 603| Kahului
# Processing Record 322 of 603| Harnosand
# Processing Record 323 of 603| Nefteyugansk
# Processing Record 324 of 603| Clyde River
# Processing Record 325 of 603| Maskinonge
# Processing Record 326 of 603| Halifax
# Processing Record 327 of 603| Faanui
# Processing Record 328 of 603| Mitsamiouli
# City not found. Skipping..........
# Processing Record 329 of 603| Sibolga
# Processing Record 330 of 603| Ahipara
# Processing Record 331 of 603| Bullhead City
# Processing Record 332 of 603| Filingue
# Processing Record 333 of 603| Severodvinsk
# Processing Record 334 of 603| Menongue
# Processing Record 335 of 603| Gat
# Processing Record 336 of 603| Shenjiamen
# Processing Record 337 of 603| Hervey Bay
# Processing Record 338 of 603| Gwanda
# Processing Record 339 of 603| High Level
# Processing Record 340 of 603| La Tuque
# Processing Record 341 of 603| Stromness
# Processing Record 342 of 603| Dodge City
# Processing Record 343 of 603| Narsaq
# Processing Record 344 of 603| Chuguyevka
# Processing Record 345 of 603| Sri Aman
# Processing Record 346 of 603| Polunochnoye
# Processing Record 347 of 603| Homer
# Processing Record 348 of 603| Tateyama
# City not found. Skipping..........
# Processing Record 349 of 603| Griffith
# Processing Record 350 of 603| Plouzane
# City not found. Skipping..........
# Processing Record 351 of 603| Dalvik
# Processing Record 352 of 603| Namatanai
# Processing Record 353 of 603| Ampanihy
# City not found. Skipping..........
# Processing Record 354 of 603| Havelock
# Processing Record 355 of 603| Luquillo
# Processing Record 356 of 603| Moussoro
# Processing Record 357 of 603| Gimli
# Processing Record 358 of 603| Juneau
# Processing Record 359 of 603| Khorinsk
# Processing Record 360 of 603| Saint George
# Processing Record 361 of 603| Aklavik
# Processing Record 362 of 603| Baracoa
# Processing Record 363 of 603| Mehamn
# Processing Record 364 of 603| Zaraza
# Processing Record 365 of 603| Chilmari
# Processing Record 366 of 603| Naron
# Processing Record 367 of 603| Svetlopolyansk
# Processing Record 368 of 603| Tanabe
# Processing Record 369 of 603| Dicabisagan
# Processing Record 370 of 603| Igarka
# Processing Record 371 of 603| Dhidhdhoo
# Processing Record 372 of 603| Havre-Saint-Pierre
# City not found. Skipping..........
# Processing Record 373 of 603| Houma
# Processing Record 374 of 603| Shipitsyno
# Processing Record 375 of 603| Tecoanapa
# Processing Record 376 of 603| Kargasok
# Processing Record 377 of 603| Serra Talhada
# Processing Record 378 of 603| Haines Junction
# Processing Record 379 of 603| Madison
# Processing Record 380 of 603| Abu Kamal
# Processing Record 381 of 603| Asosa
# Processing Record 382 of 603| Marsh Harbour
# City not found. Skipping..........
# Processing Record 383 of 603| Ostrovnoy
# Processing Record 384 of 603| Searcy
# Processing Record 385 of 603| Kharabali
# Processing Record 386 of 603| La Sarre
# Processing Record 387 of 603| Kenora
# Processing Record 388 of 603| Tsumeb
# Processing Record 389 of 603| Labuhan
# Processing Record 390 of 603| Noumea
# Processing Record 391 of 603| Mount Isa
# Processing Record 392 of 603| Dawlatabad
# Processing Record 393 of 603| Payo
# City not found. Skipping..........
# Processing Record 394 of 603| Hinton
# City not found. Skipping..........
# Processing Record 395 of 603| Nara
# Processing Record 396 of 603| Puerto Cabello
# Processing Record 397 of 603| Hirara
# Processing Record 398 of 603| Takoradi
# City not found. Skipping..........
# Processing Record 399 of 603| Chalmette
# Processing Record 400 of 603| Buala
# Processing Record 401 of 603| Rameswaram
# Processing Record 402 of 603| Praia da Vitoria
# Processing Record 403 of 603| Andra
# Processing Record 404 of 603| Pitimbu
# Processing Record 405 of 603| Maku
# Processing Record 406 of 603| Port Blair
# Processing Record 407 of 603| Kawakawa
# Processing Record 408 of 603| Sao Joao da Barra
# Processing Record 409 of 603| San Vicente
# Processing Record 410 of 603| Viedma
# Processing Record 411 of 603| Pueblo Nuevo
# Processing Record 412 of 603| Filadelfia
# Processing Record 413 of 603| Broken Hill
# Processing Record 414 of 603| Birao
# Processing Record 415 of 603| Sitka
# Processing Record 416 of 603| San Andres
# Processing Record 417 of 603| Maracas
# Processing Record 418 of 603| Avera
# Processing Record 419 of 603| Hamilton
# Processing Record 420 of 603| Mabaruma
# Processing Record 421 of 603| Naryan-Mar
# Processing Record 422 of 603| Kuching
# Processing Record 423 of 603| Hambantota
# Processing Record 424 of 603| Tilichiki
# Processing Record 425 of 603| Pangnirtung
# Processing Record 426 of 603| Egvekinot
# Processing Record 427 of 603| Huron
# Processing Record 428 of 603| Alugan
# Processing Record 429 of 603| De-Kastri
# Processing Record 430 of 603| Goroka
# Processing Record 431 of 603| Mae Hong Son
# City not found. Skipping..........
# Processing Record 432 of 603| Jacareacanga
# Processing Record 433 of 603| Keita
# Processing Record 434 of 603| Tiznit
# Processing Record 435 of 603| Praia
# Processing Record 436 of 603| Manama
# Processing Record 437 of 603| Concord
# Processing Record 438 of 603| Sidi Ali
# Processing Record 439 of 603| Grants
# Processing Record 440 of 603| Ulaanbaatar
# Processing Record 441 of 603| Saint-Marc-des-Carrieres
# Processing Record 442 of 603| Contamana
# Processing Record 443 of 603| La Baneza
# City not found. Skipping..........
# Processing Record 444 of 603| Tayga
# Processing Record 445 of 603| Seydi
# Processing Record 446 of 603| Kambja
# Processing Record 447 of 603| Maragogi
# City not found. Skipping..........
# Processing Record 448 of 603| Saint-Pierre
# Processing Record 449 of 603| Sisimiut
# Processing Record 450 of 603| Yaypan
# Processing Record 451 of 603| Lebowakgomo
# Processing Record 452 of 603| Tazovskiy
# Processing Record 453 of 603| Araouane
# City not found. Skipping..........
# Processing Record 454 of 603| Port Augusta
# Processing Record 455 of 603| Klaksvik
# Processing Record 456 of 603| Mahebourg
# Processing Record 457 of 603| Laguna
# Processing Record 458 of 603| Constitucion
# Processing Record 459 of 603| Charlestown
# Processing Record 460 of 603| Daule
# Processing Record 461 of 603| Gujranwala
# Processing Record 462 of 603| Liverpool
# Processing Record 463 of 603| Halmstad
# Processing Record 464 of 603| Mangrol
# Processing Record 465 of 603| Payson
# Processing Record 466 of 603| Camacha
# Processing Record 467 of 603| Souillac
# Processing Record 468 of 603| Akdepe
# Processing Record 469 of 603| Kano
# Processing Record 470 of 603| Baykit
# Processing Record 471 of 603| Pandamatenga
# Processing Record 472 of 603| Aleksandrov Gay
# Processing Record 473 of 603| Fuerte Olimpo
# Processing Record 474 of 603| Calama
# Processing Record 475 of 603| Pacific Grove
# Processing Record 476 of 603| Vao
# Processing Record 477 of 603| Santa Rosa
# Processing Record 478 of 603| Namibe
# Processing Record 479 of 603| Quatre Cocos
# Processing Record 480 of 603| Cedar City
# Processing Record 481 of 603| Navrongo
# Processing Record 482 of 603| Timra
# City not found. Skipping..........
# Processing Record 483 of 603| Beyneu
# Processing Record 484 of 603| Harrismith
# Processing Record 485 of 603| Elko
# Processing Record 486 of 603| Leningradskiy
# Processing Record 487 of 603| Chapais
# Processing Record 488 of 603| Hima
# Processing Record 489 of 603| Kieta
# Processing Record 490 of 603| Bambanglipuro
# Processing Record 491 of 603| Tautira
# Processing Record 492 of 603| Pevek
# Processing Record 493 of 603| Maumere
# Processing Record 494 of 603| Collie
# Processing Record 495 of 603| Champerico
# Processing Record 496 of 603| Hualmay
# Processing Record 497 of 603| Aripuana
# Processing Record 498 of 603| Golden
# Processing Record 499 of 603| Okhotsk
# Processing Record 500 of 603| Varhaug
# Processing Record 501 of 603| Praya
# Processing Record 502 of 603| Iquique
# Processing Record 503 of 603| Sedan
# Processing Record 504 of 603| Arlit
# Processing Record 505 of 603| Yanam
# Processing Record 506 of 603| Nakusp
# Processing Record 507 of 603| Kato Mazarakion
# City not found. Skipping..........
# Processing Record 508 of 603| Saint-Louis
# Processing Record 509 of 603| Surab
# Processing Record 510 of 603| Ahar
# Processing Record 511 of 603| Tete
# Processing Record 512 of 603| Hay River
# Processing Record 513 of 603| Kandi
# Processing Record 514 of 603| Vuktyl
# Processing Record 515 of 603| Benton Harbor
# Processing Record 516 of 603| Cassilandia
# Processing Record 517 of 603| Kutum
# Processing Record 518 of 603| Poli
# Processing Record 519 of 603| Tyup
# Processing Record 520 of 603| Kamenka
# Processing Record 521 of 603| Salta
# Processing Record 522 of 603| Gerede
# Processing Record 523 of 603| Verkhnevilyuysk
# Processing Record 524 of 603| Tessalit
# City not found. Skipping..........
# City not found. Skipping..........
# Processing Record 525 of 603| Byron Bay
# Processing Record 526 of 603| Saldanha
# Processing Record 527 of 603| Grindavik
# Processing Record 528 of 603| Vestmanna
# Processing Record 529 of 603| Leeton
# Processing Record 530 of 603| Hamada
# Processing Record 531 of 603| Babusnica
# Processing Record 532 of 603| Yar-Sale
# Processing Record 533 of 603| Agapovka
# Processing Record 534 of 603| Ferrol
# Processing Record 535 of 603| Kysyl-Syr
# Processing Record 536 of 603| Nancha
# Processing Record 537 of 603| Wanaka
# Processing Record 538 of 603| Cap Malheureux
# Processing Record 539 of 603| Puli
# Processing Record 540 of 603| Mpika
# Processing Record 541 of 603| Mendi
# Processing Record 542 of 603| Zhuhai
# Processing Record 543 of 603| Qidong
# Processing Record 544 of 603| Fort Smith
# Processing Record 545 of 603| Smirnykh
# Processing Record 546 of 603| Biak
# Processing Record 547 of 603| Borgosesia
# City not found. Skipping..........
# Processing Record 548 of 603| Morant Bay
# Processing Record 549 of 603| Gurupi
# City not found. Skipping..........
# City not found. Skipping..........
# Processing Record 550 of 603| Taltal
# City not found. Skipping..........

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherdict = {
    "City": cityname,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": maxtemp,
    "Wind Speed": windspeed
}
weatherdata = pd.DataFrame(weatherdict)
weatherdata.count()
# Out:
# City          550
# Cloudiness    550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
weatherdata.to_csv("../Output_csv/weatherData.csv")
weatherdata.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            Lagoa           0      PT  1566515815        61  37.14   -8.45
# 1        Carnarvon          15      ZA  1566515785        25 -30.97   22.13
# 2          Mataura          77      NZ  1566515711        86 -46.19  168.86
# 3          Ushuaia          40      AR  1566515774        75 -54.81  -68.31
# 4  Bambous Virieux          40      MU  1566515823        94 -20.34   57.76
#
#    Max Temp  Wind Speed
# 0    299.15        2.60
# 1    287.90        3.85
# 2    283.71        0.89
# 3    278.15        1.50
# 4    293.15        3.60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weatherdata["Lat"], weatherdata["Max Temp"], marker="o", s=10)
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../Output_Plots/Max_Temp_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weatherdata["Lat"], weatherdata["Humidity"], marker="o", s=10)
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../Output_Plots/Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherdata["Lat"], weatherdata["Cloudiness"], marker="o", s=10)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../Output_Plots/Cloudiness_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherdata["Lat"], weatherdata["Wind Speed"], marker="o", s=10)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../Output_Plots/Wind_Speed_vs_Latitude.png")
plt.show()
